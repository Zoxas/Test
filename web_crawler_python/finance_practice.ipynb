# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.stockdog.com.tw/stockdog/index.php?m=overview&sid=1101+%E5%8F%B0%E6%B3%A5"
head = {"User-Agent":"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.73 Safari/537.36"}

# %%
rs = requests.session()
res =  rs.get(url,headers = head)
print res.text
# Out:
#
# <!DOCTYPE html><html xmlns="https://www.w3.org/1999/xhtml" xml:lang="zh">
# <head>
# <meta name="msvalidate.01" content="3764D27CDB130C3A8E503E7FF8B5B28F" />
# <meta name="google-site-verification" content="0fOUYR1Hn_d2EBP9qlLwukSoK1VtspmJP6LMb_G73LQ" />
# <meta name="alexaVerifyID" content="GQTKRctE0WejXC6jTID7sDp6agc" />
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta property="og:type" content="product"/>
# <meta property="og:url" content="https://www.stockdog.com.tw/stockdog/"/>
# <meta property="og:locale" content="zh-TW"/>
# <meta property="og:image" content="https://www.stockdog.com.tw/stockdog/images/logo.png"/>
# <meta property="og:site_name" content="股狗網-股市籌碼分析"/>
# <meta property="og:description" content="每日最新的台股資料。 提供券商每日進出資料，分析主力進出。個股買賣日報讓你掌握賣賣個股時機！"/>
# <meta property="fb:app_id" content="268329956608070" />
# <meta name="keywords" content="股狗,股狗網,,,StockDog,籌碼分析,股市籌碼分析,籌碼面,主力,買賣日報,券商進出,券商分點,權證,權證日報,創新高,十年高,五年高,三年高,一年高,創新低,吃貨,出貨" />
# ...

# %%
import re

m = re.findall('document.getElementById\(\'g\d+\'\).innerHTML=\'<iframe src=\"(.*?)\"',res.text)
for URL in m:
    print "https://www.stockdog.com.tw/stockdog/"+URL
# Out:
# https://www.stockdog.com.tw/stockdog/guest_show.php?sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb3
# https://www.stockdog.com.tw/stockdog/guest_show.php?click_btn3=1&click_btn6=1&click_btn7=1&sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb1
# https://www.stockdog.com.tw/stockdog/guest_show.php?date2=2015-12-04&sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb4
# https://www.stockdog.com.tw/stockdog/guest_show.php?sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb5&sdate=2012-06-11&edate=2015-12-07
# https://www.stockdog.com.tw/stockdog/guest_show.php?sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb6
# https://www.stockdog.com.tw/stockdog/guest_show.php?sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb7
# https://www.stockdog.com.tw/stockdog/guest_show.php?date=2015-12-04&sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb8
# https://www.stockdog.com.tw/stockdog/guest_show.php?sid=1101&GStype=1de95bb3b35d534e90fda0c4a39f7cddb9&day=120
# ...

# %%
res2 = rs.get("https://www.stockdog.com.tw/stockdog/"+m[0],headers = head)
print res2.text
# Out:
# ﻿<!DOCTYPE HTML>
# <html>
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=utf-8">
# <title>2015-12-04 台泥(1101) 走勢圖</title>
# <script type=text/javascript src=js/jquery/1.8.2/jquery.min.js></script>
# ...
