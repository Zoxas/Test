# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url = "http://bluelove1968.pixnet.net/blog/post/222283186-%E8%AB%96p,np,np-hard,np-complete%E5%95%8F%E9%A1%8C"
res = requests.get(url)
soup = BeautifulSoup(res.text,"lxml")
print soup.prettify()
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html itemscope="" itemtype="http://schema.org/Blog" lang="zh-TW">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="èè²ææ·" property="og:site_name"/>
#   <meta content="zh_TW" property="og:locale"/>
#   <meta content="http://bluelove1968.pixnet.net/blog/post/222283186" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="è«P,NP,NP-hard,NP-completeåé¡ @ èè²ææ· :: çå®¢é¦ PIXNET ::" property="og:title"/>
#   <meta content="è«P,NP,NP-hard,NP-completeåé¡å®ç¾©:        åºæ¬ä¸éä¸çä¸çåé¡å¯ä»¥åé¡æçº        1) Unsolvable Problem        2) Intrac" property="og:description"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# ...

# %%
for item in soup.select("body "):
    print item
