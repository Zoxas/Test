# %%
# %pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd

# %%
plot(np.arange(10))

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure() #空窗口

# %%
ax1 = fig.add_subplot(2, 2, 1) # 2x2 圖像的第一個
ax2 = fig.add_subplot(2, 2, 2) # 2x2 圖像的第二個
ax3 = fig.add_subplot(2, 2, 3) # 2x2 圖像的第三個

# %%
from numpy.random import randn

# %%
ax3.plot(randn(50).cumsum() , 'k--')

# %%
fig

# %%
_ = ax1.hist(randn(100), bins=20, color='k' , alpha=0.3)

# %%
fig

# %%
ax2.scatter(np.arange(30),np.arange(30) + 3*randn(30))

# %%
fig

# %%
fig2 , axes = plt.subplots(2,2, sharex=True, sharey = True)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001AEF39E8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001B325390>]], dtype=object)

# %%
#修改 各圖之間的間距
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500), bins=50, color='k' , alpha= 0.5)

fig2.subplots_adjust(wspace=0, hspace=0)

# %%
fig2

# %%
# 顏色 標記 線型
plt.plot(randn(30).cumsum() , 'ko--')

# %%
plot(randn(30).cumsum() , color= 'k' , linestyle= 'dashed' , marker='o')

# %%
data = randn(30).cumsum()
plt.plot(data, 'k--' , label='Default') # 沒 drawstyle 默認 線姓插值

# %%
# drawstyle 用法
plt.plot(data, 'k-' , drawstyle='steps-post' , label='steps-post')

# %%
fig = plt.figure() ; ax  = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())

# %%
#設置 標題 軸標籤 刻度標籤
ticks = ax.set_xticks([0, 250, 500, 750, 1000])

# %%
fig

# %%
labels = ax.set_xticklabels([ 'one', 'two','three','four', 'five'],rotation=30, fontsize='small' )
fig

# %%
ax.set_title('My first matplotlib plot')
fig

# %%
ax.set_xlabel('Stages')
fig

# %%
# 添加圖例
fig = plt.figure() ; ax  = fig.add_subplot(1,1,1)

# %%
ax.plot(randn(1000).cumsum() , 'k' , label='one')
fig

# %%
ax.plot(randn(1000) .cumsum() , 'k--' , label='two' )
fig

# %%
ax.plot(randn(1000).cumsum() , 'k.' , label= 'three')
fig

# %%
# loc 告訴 matplotlib 要把圖例放在哪
ax.legend(loc= 'best')
fig

# %%
txt = ax.text(220 , 20 , 'Hello world!' ,family='monospace' , fontsize=10)
fig

# %%
txt.remove()
fig

# %%
# 畫常見圖形
fig = plt.figure ()
ax =fig.add_subplot(1,1,1)

# %%
rect = plt.Rectangle((0.2,0.8),0.4,0.15,color='g',alpha=0.3)
circ = plt.Circle((0.8,0.2),0.2,color='b',alpha=0.5 )
pgon = plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color = 'r',alpha = 0.7)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
fig

# %%
rect.remove()
fig

# %%
# pandas的繪圖 -> 會傳遞給 matplotlib
from pandas import *
s =Series(np.random.randn(10).cumsum() , index=np.arange(0, 100, 10))
s.plot()

# %%
df = DataFrame(np.random.randn(10, 4).cumsum(0) ,
columns= ['A','B','C','D'],
index=np.arange(0, 100, 10))
df.loc('best')
df.plot()

# %%
#柱狀圖
fig , axes = plt.subplots(2, 1)
data = Series (np.random.rand(16), index = list('abcdefghijklmnop'))

# %%
data.plot(kind='bar' , ax=axes[0] , color='k', alpha=0.7)

# %%
fig

# %%
data.plot(kind='barh' , ax=axes[1] , color='k', alpha=0.7)

# %%
fig

# %%
df = DataFrame(np.random.randn(6, 4),
               index = ['one','two','three','four','five','six'],
               columns = pd.Index(['A','B','C','D'],name = 'Genus'))
df
# Out:
# Genus         A         B         C         D
# one   -1.178946 -0.229940  0.777240 -0.061437
# two    2.169729 -0.499869 -1.013135 -0.565955
# three  0.269808  1.799837 -1.465936  1.983009
# four   0.193253  0.117809  1.535792 -0.563363
# five   1.156253 -1.180620  1.046087 -0.922775
# six   -1.944810 -0.243357  0.394675  1.229779

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh' , stacked=True, alpha=0.5)

# %%
# 直方圖

comp1 = np.random.normal(0, 1, size=200) # N(0 , 1)
comp2 = np.random.normal(10, 2, size=200) # N(10, 4)
values = Series(np.concatenate( [comp1, comp2] )) #加入陣列的順序沿著一個現有的軸
values
# Out:
# 0      -0.025665
# 1       0.069638
# 2      -1.431355
# 3      -0.326478
# 4       0.370832
# 5      -1.419326
# 6       0.226627
# 7       0.144747
# 8      -0.877904
# 9       0.323553
# 10     -0.194337
# 11     -0.920201
# 12     -0.908665
# 13     -0.626356
# 14      0.836731
# 15      0.534421
# 16     -0.825104
# 17     -0.482449
# 18      0.061014
# 19     -0.507871
# 20      1.554417
# 21     -1.810489
# 22      0.859747
# 23     -0.441267
# 24      1.029637
# 25      0.443000
# 26      0.810692
# 27      0.846930
# 28     -1.300840
# 29     -0.061864
#          ...
# 370    11.620489
# 371     7.901776
# 372     7.573778
# 373    10.294132
# 374     9.933617
# 375     9.499023
# 376    10.751311
# 377    10.758032
# 378     8.813482
# 379    10.938828
# 380     8.790637
# 381     9.555088
# 382     9.065572
# 383     6.117110
# 384     9.109493
# 385    11.249280
# 386    11.967335
# 387    13.052525
# 388    12.759820
# 389    11.504024
# 390    11.900517
# ...

# %%
values.hist(bins=100, alpha=0.3, color= 'k' , normed=True)

# %%
values.plot( kind='kde' , style= 'k--')
